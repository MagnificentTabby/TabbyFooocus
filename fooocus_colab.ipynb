# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/MagnificentTabby/TabbyFooocus.git
# %cd /content/TabbyFooocus
# !find /content/drive/MyDrive/Models/loras -iname "*.safetensors" -exec cp {} /content/TabbyFooocus/models/loras \;
# Out:
# Mounted at /content/drive
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 71.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.18.2
#     Uninstalling pygit2-1.18.2:
#       Successfully uninstalled pygit2-1.18.2
# ...
# /content
# Cloning into 'TabbyFooocus'...
# remote: Enumerating objects: 6545, done.
# remote: Total 6545 (delta 0), reused 0 (delta 0), pack-reused 6545 (from 1)
# Receiving objects: 100% (6545/6545), 33.26 MiB | 22.03 MiB/s, done.
# Resolving deltas: 100% (3719/3719), done.
# /content/TabbyFooocus

# %%
# !python /content/TabbyFooocus/entry_with_update.py --share --always-high-vram
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['/content/TabbyFooocus/entry_with_update.py', '--share', '--always-high-vram']
# /content/TabbyFooocus/build_launcher.py:9: SyntaxWarning: invalid escape sequence '\p'
#   .\python_embeded\python.exe -s Fooocus\entry_with_update.py {cmds} %*
# Python 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/TabbyFooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 10.3MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/TabbyFooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 10.7MB/s]
# ...

# %%
# %cd /content/drive/MyDrive/Models/loras
# !for filename in *; do echo "${filename}"; done
# !for filename in *; do ln -s "${filename}" "/content/TabbyFooocus/models/loras/"${filename} ; done
# Out:
# /content/drive/MyDrive/Models/loras
# add-detail-xl.safetensors
# BondageXcrossV1--In Stocks Pose.safetensors
# btty.safetensors
# Caged_Captive-000007.safetensors
# jia_SDXL_2_s.safetensors
# JJsTempleRuin_XL.safetensors
# Leashes_and_Collars__SDXL.safetensors
# LoraANGXL4Z_speculum_insertion_v2.safetensors
# Metal_Stocks_XL-000005.safetensors
# Nike_Pros.safetensors
# pony
# ThiccAndCuteV3.safetensors
# XL_marymorgan_v8.safetensors
# ln: target 'Pose.safetensors': No such file or directory

# %%
ls -l /content/TabbyFooocus/models/loras/
# Out:
# total 0
# lrwxrwxrwx 1 root root 25 Aug 24 22:02 add-detail-xl.safetensors -> add-detail-xl.safetensors
# lrwxrwxrwx 1 root root 16 Aug 24 22:02 btty.safetensors -> btty.safetensors
# lrwxrwxrwx 1 root root 32 Aug 24 22:02 Caged_Captive-000007.safetensors -> Caged_Captive-000007.safetensors
# lrwxrwxrwx 1 root root 24 Aug 24 22:02 jia_SDXL_2_s.safetensors -> jia_SDXL_2_s.safetensors
# lrwxrwxrwx 1 root root 28 Aug 24 22:02 JJsTempleRuin_XL.safetensors -> JJsTempleRuin_XL.safetensors
# lrwxrwxrwx 1 root root 37 Aug 24 22:02 Leashes_and_Collars__SDXL.safetensors -> Leashes_and_Collars__SDXL.safetensors
# lrwxrwxrwx 1 root root 45 Aug 24 22:02 LoraANGXL4Z_speculum_insertion_v2.safetensors -> LoraANGXL4Z_speculum_insertion_v2.safetensors
# lrwxrwxrwx 1 root root 34 Aug 24 22:02 Metal_Stocks_XL-000005.safetensors -> Metal_Stocks_XL-000005.safetensors
# lrwxrwxrwx 1 root root 21 Aug 24 22:02 Nike_Pros.safetensors -> Nike_Pros.safetensors
# ...
